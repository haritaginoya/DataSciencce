# %% [markdown]
# <a href="https://colab.research.google.com/github/haritaginoya/DataSciencce/blob/master/seaborn_p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x = [1,3,5]
y = [3,4,5]

plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
x=[1,3,8,5,9]
y=[2,5,2,6,8]
plt.plot(x,y)
plt.title("Mon titre")
plt.xlabel("Axe x")
plt.ylabel("Axe y")
# Out:
# Text(0, 0.5, 'Axe y')

# %%
x = [1,2,4,5]
y = [3,4,6,7]

x1 = [3,4,2,5]
y1 = [5,7,8,9]

plt.plot(x,y)
plt.plot(x1,y1)

# %%
import matplotlib.pyplot as plt


x = [1,2,4,7]
y = [10,30,40,60]

plt.plot(x,y,label='cloth',color='blue')
plt.title('practice')
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = [6, 2, 1, 1.5, 9]
x1 = [1, 3, 5, 7, 10]
x2 = [2, 4, 4, 8, 9]

n = len(y)
x = np.arange(n)
width = 0.4
print(x)

fig , ax = plt.subplots()

bar1 = ax.bar(x - width/2,x1,width,label= 'first')
bar2 = ax.bar(x + width/2,x2,width,label = 'second')

# ax.set_xticks(x)
# ax.set_xticklabels([f'Y={i}' for i in y])


# plt.bar(x,y,label='line',color='pink')
# plt.bar(x1,y1,label='line-1',color='red')
# plt.legend()
# Out:
# [0 1 2 3 4]
