# %% [markdown]
# <a href="https://colab.research.google.com/github/haritaginoya/DataSciencce/blob/master/datacleaning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame()
df['subject']=['s1','s2','s3']
df = df.assign(marks=[45,56,76],mark2 = [23,45,np.nan])

# %%
df
# Out:
#   subject  marks  mark2
# 0      s1     45   23.0
# 1      s2     56   45.0
# 2      s3     76    NaN

# %%
df.count()
# Out:
# subject    3
# marks      3
# mark2      2
# dtype: int64

# %%
df.describe()
# Out:
#            marks      mark2
# count   3.000000   2.000000
# mean   59.000000  34.000000
# std    15.716234  15.556349
# min    45.000000  23.000000
# 25%    50.500000  28.500000
# 50%    56.000000  34.000000
# 75%    66.000000  39.500000
# max    76.000000  45.000000

# %%
df.head()
# Out:
#   subject  marks  mark2
# 0      s1     45   23.0
# 1      s2     56   45.0
# 2      s3     76    NaN

# %%
data = {'name' : ['harita','gopi','vivek','tanvi'] , 'per' : [23,45,67,89] , 'course' : ['B.sci' , 'B.Ed','BA','BA'] }
df = pd.DataFrame(data)
df
# Out:
#      name  per course
# 0  harita   23  B.sci
# 1    gopi   45   B.Ed
# 2   vivek   67     BA
# 3   tanvi   89     BA

# %%
g = df.groupby(['course'])
g['per'].agg(np.mean)
# Out:
# <ipython-input-30-4c470e9c8ef2>:2: FutureWarning: The provided callable <function mean at 0x7db677bf55a0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   g['per'].agg(np.mean)
# course
# B.Ed     45.0
# B.sci    23.0
# BA       78.0
# Name: per, dtype: float64
